# %%
import hashlib
val = input("Enter your value: ")
print(val)
hcode = hashlib.md5(val.encode())
print("The byte equivalent of hash is : ", end ="")
print(hcode)
# Out:
# Enter your value: aman
# aman
# The byte equivalent of hash is : <md5 HASH object @ 0x7fa6126a2b10>

# %%
import hashlib
result = hashlib.md5(b'ShapeAI rocks')
